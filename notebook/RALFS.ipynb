# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
# !git clone https://github.com/ashaduzzaman-sarker/RALFS.git
# %cd RALFS

# !ls

# %%
# !pip install --upgrade pip
# !pip install -e .

# %%
# !pip install --upgrade poetry -q
# !poetry install

# %%
# !poetry run python -m src.cli --help
# !chmod +x scripts/preprocess.sh
# !bash scripts/preprocess.sh
# ./scripts/preprocess.sh

# %%
# !chmod +x scripts/run_build_index.sh
# !bash scripts/run_build_index.sh

# %%
# !poetry run python examples/retrieval_demo.py

# %%
# !chmod +x scripts/run_hybrid_index.sh
# !bash scripts/run_hybrid_index.sh

# %%
# !poetry run python examples/hybrid_demo.py

# %%
# !chmod +x scripts/train_fid.sh
# !bash scripts/train_fid.sh

# %%
# !chmod +x scripts/evaluate.sh
# !bash scripts/evaluate.sh

# %%
# !chmod +x scripts/run_human_eval.sh
# !bash scripts/run_human_eval.sh
